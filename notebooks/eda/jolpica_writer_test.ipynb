# %%
import os 
import sys
import pandas as pd
import s3fs
from pathlib import Path
from dotenv import load_dotenv

# %%
load_dotenv(Path.cwd().parent / ".env")
# Out:
# True

# %%
repo_root = Path.cwd().parent
sys.path.insert(0, str(repo_root))

# %%
from ingestion.jolpica.helper import logging_setup
from ingestion.jolpica.race_results import get_race_results
from ingestion.jolpica.driver_standings import get_driver_standings
from ingestion.jolpica.constructor_standings import get_constructor_standings
from ingestion.jolpica.race_schedule import get_season_race_data
from ingestion.jolpica.pit_stops import get_pit_stop_time_data
from ingestion.jolpica.writer import df_write_to_s3_raw

# %%
logging_setup()
df = get_race_results(2026)
s3_path = df_write_to_s3_raw(df=df, source="jolpica", year="2026", endpoint="race_results")
print(f"Written to: {s3_path}")

fs = s3fs.S3FileSystem(
    key=os.getenv("AWS_ACCESS_KEY_ID"),
    secret=os.getenv("AWS_SECRET_ACCESS_KEY"),
    client_kwargs={"region_name": os.getenv("AWS_REGION")},
)

bucket = os.getenv("S3_BUCKET_RAW")

with fs.open(f"s3://{bucket}/jolpica/2026/race_results.parquet", "rb") as f:
    df = pd.read_parquet(f)

print(df.head(5))
# Out:
# [2026-03-18 11:43:27] INFO [ingestion.jolpica.race_results] Getting race result data for 2026
# [2026-03-18 11:43:29] INFO [ingestion.jolpica.helper] 2026/results: offset 0/44
# [2026-03-18 11:43:29] INFO [ingestion.jolpica.race_results] Race results 2026: 44 rows across 2 rounds
# Written to: s3://f1-raw-395249043157/jolpica/2026/race_results.parquet
#    season  round              race_name                         circuit  \
# 0    2026      1  Australian Grand Prix  Albert Park Grand Prix Circuit
# 1    2026      1  Australian Grand Prix  Albert Park Grand Prix Circuit
# 2    2026      1  Australian Grand Prix  Albert Park Grand Prix Circuit
# 3    2026      1  Australian Grand Prix  Albert Park Grand Prix Circuit
# 4    2026      1  Australian Grand Prix  Albert Park Grand Prix Circuit
#
#          date  driver_id driver_code            driver_name constructor  grid  \
# 0  2026-03-08    russell         RUS         George Russell    Mercedes     1
# 1  2026-03-08  antonelli         ANT  Andrea Kimi Antonelli    Mercedes     2
# 2  2026-03-08    leclerc         LEC        Charles Leclerc     Ferrari     4
# 3  2026-03-08   hamilton         HAM         Lewis Hamilton     Ferrari     7
# 4  2026-03-08     norris         NOR           Lando Norris     McLaren     6
#
#    position  points    status  fastest_lap_rank   source  \
# 0         1    25.0  Finished               6.0  jolpica
# 1         2    18.0  Finished               3.0  jolpica
# 2         3    15.0  Finished               5.0  jolpica
# 3         4    12.0  Finished               4.0  jolpica
# 4         5    10.0  Finished               2.0  jolpica
#
#                         ingested_at
# 0  2026-03-18T21:43:29.472552+00:00
# 1  2026-03-18T21:43:29.472552+00:00
# 2  2026-03-18T21:43:29.472552+00:00
# 3  2026-03-18T21:43:29.472552+00:00
# 4  2026-03-18T21:43:29.472552+00:00

# %%
logging_setup()
df = get_driver_standings(2026)
s3_path = df_write_to_s3_raw(df=df, source="jolpica", year="2026", endpoint="driver_standings")
print(f"Written to: {s3_path}")

fs = s3fs.S3FileSystem(
    key=os.getenv("AWS_ACCESS_KEY_ID"),
    secret=os.getenv("AWS_SECRET_ACCESS_KEY"),
    client_kwargs={"region_name": os.getenv("AWS_REGION")},
)

bucket = os.getenv("S3_BUCKET_RAW")

with fs.open(f"s3://{bucket}/jolpica/2026/driver_standings.parquet", "rb") as f:
    df = pd.read_parquet(f)

print(df.head(5))
# Out:
# [2026-03-18 11:45:02] INFO [ingestion.jolpica.driver_standings] Getting driver standing data for 2026
# [2026-03-18 11:45:04] INFO [ingestion.jolpica.helper] 2026/driverStandings: offset 0/22
# [2026-03-18 11:45:04] INFO [ingestion.jolpica.driver_standings] Driver standings for 2026: 22 rows across 1 rounds
# Written to: s3://f1-raw-395249043157/jolpica/2026/driver_standings.parquet
#    season  round  driver_id driver_code            driver_name  driver_dob  \
# 0    2026      2    russell         RUS         George Russell  1998-02-15
# 1    2026      2  antonelli         ANT  Andrea Kimi Antonelli  2006-08-25
# 2    2026      2    leclerc         LEC        Charles Leclerc  1997-10-16
# 3    2026      2   hamilton         HAM         Lewis Hamilton  1985-01-07
# 4    2026      2    bearman         BEA         Oliver Bearman  2005-05-08
#
#   driver_country   constructor constructor_country  position  points  wins  \
# 0        British      Mercedes              German         1    51.0     1
# 1        Italian      Mercedes              German         2    47.0     1
# 2     Monegasque       Ferrari             Italian         3    34.0     0
# 3        British       Ferrari             Italian         4    33.0     0
# 4        British  Haas F1 Team            American         5    17.0     0
#
#     source                       ingested_at
# 0  jolpica  2026-03-18T21:45:04.180898+00:00
# 1  jolpica  2026-03-18T21:45:04.180898+00:00
# 2  jolpica  2026-03-18T21:45:04.180898+00:00
# 3  jolpica  2026-03-18T21:45:04.180898+00:00
# 4  jolpica  2026-03-18T21:45:04.180898+00:00

# %%
logging_setup()
df = get_constructor_standings(2026)
s3_path = df_write_to_s3_raw(df=df, source="jolpica", year="2026", endpoint="constructor_standings")
print(f"Written to: {s3_path}")

fs = s3fs.S3FileSystem(
    key=os.getenv("AWS_ACCESS_KEY_ID"),
    secret=os.getenv("AWS_SECRET_ACCESS_KEY"),
    client_kwargs={"region_name": os.getenv("AWS_REGION")},
)

bucket = os.getenv("S3_BUCKET_RAW")

with fs.open(f"s3://{bucket}/jolpica/2026/constructor_standings.parquet", "rb") as f:
    df = pd.read_parquet(f)

print(df.head(5))
# Out:
# [2026-03-18 11:45:44] INFO [ingestion.jolpica.constructor_standings] Getting constructor standing data for 2026
# [2026-03-18 11:45:45] INFO [ingestion.jolpica.helper] 2026/constructorStandings: offset 0/11
# [2026-03-18 11:45:45] INFO [ingestion.jolpica.constructor_standings] Constructor standings for 2026: 11 rows across 1 rounds
# Written to: s3://f1-raw-395249043157/jolpica/2026/constructor_standings.parquet
#    season  round constructor_id   constructor constructor_country  position  \
# 0    2026      2       mercedes      Mercedes              German         1
# 1    2026      2        ferrari       Ferrari             Italian         2
# 2    2026      2        mclaren       McLaren             British         3
# 3    2026      2           haas  Haas F1 Team            American         4
# 4    2026      2       red_bull      Red Bull            Austrian         5
#
#    points  wins   source                       ingested_at
# 0    98.0     2  jolpica  2026-03-18T21:45:45.373097+00:00
# 1    67.0     0  jolpica  2026-03-18T21:45:45.373097+00:00
# 2    18.0     0  jolpica  2026-03-18T21:45:45.373097+00:00
# 3    17.0     0  jolpica  2026-03-18T21:45:45.373097+00:00
# 4    12.0     0  jolpica  2026-03-18T21:45:45.373097+00:00

# %%
logging_setup()
df = get_season_race_data(2026)
s3_path = df_write_to_s3_raw(df=df, source="jolpica", year="2026", endpoint="race_schedule")
print(f"Written to: {s3_path}")

fs = s3fs.S3FileSystem(
    key=os.getenv("AWS_ACCESS_KEY_ID"),
    secret=os.getenv("AWS_SECRET_ACCESS_KEY"),
    client_kwargs={"region_name": os.getenv("AWS_REGION")},
)

bucket = os.getenv("S3_BUCKET_RAW")

with fs.open(f"s3://{bucket}/jolpica/2026/race_schedule.parquet", "rb") as f:
    df = pd.read_parquet(f)

print(df.head(5))
# Out:
# [2026-03-18 11:46:40] INFO [ingestion.jolpica.race_schedule] Getting race season data for 2026
# [2026-03-18 11:46:42] INFO [ingestion.jolpica.helper] 2026/races: offset 0/22
# [2026-03-18 11:46:42] INFO [ingestion.jolpica.race_schedule] Race sessions for year: 2026 22 rows across 22 rounds
# Written to: s3://f1-raw-395249043157/jolpica/2026/race_schedule.parquet
#    season  round              race_name                         circuit  \
# 0    2026      1  Australian Grand Prix  Albert Park Grand Prix Circuit
# 1    2026      2     Chinese Grand Prix  Shanghai International Circuit
# 2    2026      3    Japanese Grand Prix                  Suzuka Circuit
# 3    2026      4       Miami Grand Prix   Miami International Autodrome
# 4    2026      5    Canadian Grand Prix       Circuit Gilles Villeneuve
#
#     race_date race_start_time    fp1_date   fp1_time    fp2_date   fp2_time  \
# 0  2026-03-08       04:00:00Z  2026-03-06  01:30:00Z  2026-03-06  05:00:00Z
# 1  2026-03-15       07:00:00Z  2026-03-13  03:30:00Z        None       None
# 2  2026-03-29       05:00:00Z  2026-03-27  02:30:00Z  2026-03-27  06:00:00Z
# 3  2026-05-03       20:00:00Z  2026-05-01  16:30:00Z        None       None
# 4  2026-05-24       20:00:00Z  2026-05-22  16:30:00Z        None       None
#
#      fp3_date   fp3_time sprint_qualy_date sprint_qualy_time  qualy_date  \
# 0  2026-03-07  01:30:00Z              None              None  2026-03-07
# 1        None       None        2026-03-13         07:30:00Z  2026-03-14
# 2  2026-03-28  02:30:00Z              None              None  2026-03-28
# 3        None       None        2026-05-01         20:30:00Z  2026-05-02
# 4        None       None        2026-05-22         20:30:00Z  2026-05-23
#
#   qualy_time   source                       ingested_at
# 0  05:00:00Z  jolpica  2026-03-18T21:46:42.364626+00:00
# 1  07:00:00Z  jolpica  2026-03-18T21:46:42.364626+00:00
# 2  06:00:00Z  jolpica  2026-03-18T21:46:42.364626+00:00
# 3  20:00:00Z  jolpica  2026-03-18T21:46:42.364626+00:00
# 4  20:00:00Z  jolpica  2026-03-18T21:46:42.364626+00:00

# %%
import boto3
s3 = boto3.client("s3", region_name=os.getenv("AWS_REGION"))
bucket = os.getenv("S3_BUCKET_RAW")
Key="jolpica/2026/race_results.parquet"
response = s3.get_object(Bucket=bucket, Key=Key)
content = response["ContentLength"]
print(content)
# Out:
# [2026-03-18 11:34:00] INFO [botocore.credentials] Found credentials in environment variables.
# 11187
